# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def v(x,y,a,b,v_0):
    suma = 0
    for n in range(1,10,2):
        suma= suma+ np.sin((n*(np.pi/2)*x)/b)*np.sinh((n*(np.pi)*y)/b )/(n*np.sinh((n*np.pi*a)/b))
        return ((4*v_0)/(np.pi))*suma

data_1 = {
    "X": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_2 = {
    "X": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [4, 4, 4, 4, 4, 4, 4, 4, 4],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_3 = {
    "X": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [2, 2, 2, 2, 2, 2, 2, 2, 2],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_4 = {
    "x": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "b": [5, 5, 5, 5, 5, 5, 5, 5, 5],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_5 = {
    "x": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [3, 3, 3, 3, 3, 3, 3, 3, 3],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}

def create_plot(data):
    df = pd.DataFrame(data)
    df['v(x,y)'] = v(df['X'], df['y'], df['a'], df['B'], df['Vo'])
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Scatter plot
    ax.scatter(df['X'], df['y'], df['v(x,y)'])

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('v(x,y)')

    plt.show()

create_plot(data_1)
create_plot(data_2)
create_plot(data_3)
create_plot(data_4)
create_plot(data_5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def v(x,y,a,b,v_0):
    suma = 0
    for n in range(1,10,2):
        suma= suma+ np.sin((n*(np.pi/2)*x)/b)*np.sinh((n*(np.pi)*y)/b )/(n*np.sinh((n*np.pi*a)/b))
        return ((4*v_0)/(np.pi))*suma

# %%
data_1 = {
    "X": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_2 = {
    "X": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [4, 4, 4, 4, 4, 4, 4, 4, 4],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_3 = {
    "X": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [2, 2, 2, 2, 2, 2, 2, 2, 2],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_4 = {
    "x": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "b": [5, 5, 5, 5, 5, 5, 5, 5, 5],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}


data_5 = {
    "x": [0.25, 0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75, 0.75],
    "y": [0.25, 0.50, 0.75, 0.25, 0.50, 0.75, 0.25, 0.50, 0.75],
    "a": [1, 1, 1, 1, 1, 1, 1, 1, 1],
    "B": [3, 3, 3, 3, 3, 3, 3, 3, 3],
    "Vo": [100, 100, 100, 100, 100, 100, 100, 100, 100]
}

# %%
def create_plot(data):
    df = pd.DataFrame(data)
    df['v(x,y)'] = v(df['X'], df['y'], df['a'], df['B'], df['Vo'])
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Scatter plot
    ax.scatter(df['X'], df['y'], df['v(x,y)'])

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('v(x,y)')

    plt.show()

# %%
create_plot(data_1)
# Out:
#       X     y  a  B   Vo     v(x,y)
# 0  0.25  0.25  1  1  100   3.664971
# 1  0.25  0.50  1  1  100   9.709307
# 2  0.25  0.75  1  1  100  22.057102
# 3  0.50  0.25  1  1  100   6.771983
# 4  0.50  0.50  1  1  100  17.940460
# 5  0.50  0.75  1  1  100  40.756210
# 6  0.75  0.25  1  1  100   8.848022
# 7  0.75  0.50  1  1  100  23.440340
# 8  0.75  0.75  1  1  100  53.250554

# %%
create_plot(data_2)

# %%
create_plot(data_3)
# Out:
# \begin{tabular}{lcccccc}
#  & X & y & a & B & Vo & v(x,y) \\
# 0 & 0.250000 & 0.250000 & 1 & 1 & 100 & 6.797167 \\
# 1 & 0.250000 & 0.500000 & 1 & 1 & 100 & 18.202833 \\
# 2 & 0.250000 & 0.750000 & 1 & 1 & 100 & 43.201676 \\
# 3 & 0.500000 & 0.250000 & 1 & 1 & 100 & 9.541412 \\
# 4 & 0.500000 & 0.500000 & 1 & 1 & 100 & 25.000000 \\
# 5 & 0.500000 & 0.750000 & 1 & 1 & 100 & 54.054665 \\
# 6 & 0.750000 & 0.250000 & 1 & 1 & 100 & 6.797167 \\
# 7 & 0.750000 & 0.500000 & 1 & 1 & 100 & 18.202833 \\
# 8 & 0.750000 & 0.750000 & 1 & 1 & 100 & 43.201676 \\
# \end{tabular}
